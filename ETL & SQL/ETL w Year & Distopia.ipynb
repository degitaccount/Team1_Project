# %%
import pandas as pd

# %%
df_15 = pd.read_csv("Resources/2015.csv") 
df_16 = pd.read_csv("Resources/2016.csv") 
df_17 = pd.read_csv("Resources/2017.csv") 
df_18 = pd.read_csv("Resources/2018.csv") 
df_19 = pd.read_csv("Resources/2019.csv") 
df_20 = pd.read_csv("Resources/2020.csv")
df_20
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# 2                          0.035014      7.628528      7.491272
# 3                          0.059616      7.621347      7.387653
# 4                          0.034837      7.556281      7.419719
# ..                              ...           ...           ...
# 148                        0.115183      3.701658      3.250141
# 149                        0.052425      3.415053      3.209547
# 150                        0.058674      3.414202      3.184198
# 151                        0.107610      3.027516      2.605684
# 152                        0.031311      2.628270      2.505530
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                10.639267        0.954330                71.900825
# 1                10.774001        0.955991                72.402504
# 2                10.979933        0.942847                74.102448
# 3                10.772559        0.974670                73.000000
# 4                11.087804        0.952487                73.200783
# ..                     ...             ...                      ...
# 148               6.625160        0.319460                45.200001
# 149               7.600104        0.540835                61.098846
# 150               7.865712        0.763093                55.617260
# 151               7.425360        0.553707                51.000000
# 152               7.462861        0.470367                52.590000
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                        0.949172   -0.059482                   0.195445
# 1                        0.951444    0.066202                   0.168489
# 2                        0.921337    0.105911                   0.303728
# 3                        0.948892    0.246944                   0.711710
# 4                        0.955750    0.134533                   0.263218
# ..                            ...         ...                        ...
# 148                      0.640881    0.082410                   0.891807
# 149                      0.900589    0.055484                   0.183541
# 150                      0.711458   -0.072064                   0.810237
# 151                      0.451314    0.016519                   0.763417
# 152                      0.396573   -0.096429                   0.933687
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                    1.972317                          1.285190
# 1                    1.972317                          1.326949
# 2                    1.972317                          1.390774
# 3                    1.972317                          1.326502
# 4                    1.972317                          1.424207
# ..                        ...                               ...
# 148                  1.972317                          0.041072
# 149                  1.972317                          0.343243
# 150                  1.972317                          0.425564
# 151                  1.972317                          0.289083
# 152                  1.972317                          0.300706
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                        1.499526                               0.961271
# 1                        1.503449                               0.979333
# 2                        1.472403                               1.040533
# 3                        1.547567                               1.000843
# 4                        1.495173                               1.008072
# ..                            ...                                    ...
# 148                      0.000000                               0.000000
# 149                      0.522876                               0.572383
# 150                      1.047835                               0.375038
# 151                      0.553279                               0.208809
# 152                      0.356434                               0.266052
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                      0.662317                  0.159670
# 1                                      0.665040                  0.242793
# 2                                      0.628954                  0.269056
# 3                                      0.661981                  0.362330
# 4                                      0.670201                  0.287985
# ..                                          ...                       ...
# 148                                    0.292814                  0.253513
# 149                                    0.604088                  0.235705
# 150                                    0.377405                  0.151349
# 151                                    0.065609                  0.209935
# 152                                    0.000000                  0.135235
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                   0.477857             2.762835
# 1                                   0.495260             2.432741
# 2                                   0.407946             2.350267
# 3                                   0.144541             2.460688
# 4                                   0.434101             2.168266
# ..                                       ...                  ...
# 148                                 0.028265             2.860198
# 149                                 0.485542             0.548445
# 150                                 0.080929             0.841031
# 151                                 0.111157             1.378751
# 152                                 0.001226             1.507236
#
# [153 rows x 20 columns]

# %%
df_20['Happiness Rank'] =  range(1, len(df_20.index)+1)

df_20 = df_20.rename(columns = {'Country name' : 'Country', 'Ladder score' : 'Happiness_Score',
                                'Explained by: Log GDP per capita' : 'Economy_GDP_per_Capita', 'Social support' : 'Family', 'Explained by: Healthy life expectancy' : 'Health_Life_Expectancy',
                                    'Explained by: Freedom to make life choices' : 'Freedom',
                                    'Explained by: Generosity' : 'Generosity1', 
                                    'Explained by: Perceptions of corruption' : 'Trust_Government_Corruption','Dystopia + residual' : 'Dystopia_Residual'})



df_19 = df_19.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region' : 'Country', 'Score' : 'Happiness_Score',
                                      'GDP per capita' : 'Economy_GDP_per_Capita', 'Social support' : 'Family',
                                      'Healthy life expectancy' : 'Health_Life_Expectancy','Freedom to make life choices' : 'Freedom'
                                     , 'Perceptions of corruption' : 'Trust_Government_Corruption'})



df_18 = df_18.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region' : 'Country', 'Score' : 'Happiness_Score',
                                      'GDP per capita' : 'Economy_GDP_per_Capita', 'Social support' : 'Family',
                                      'Healthy life expectancy' : 'Health_Life_Expectancy',
                                      'Freedom to make life choices' : 'Freedom',
                                      'Perceptions of corruption' : 'Trust_Government_Corruption'})


df_17 = df_17.rename(columns = {'Happiness.Rank':'Happiness Rank', 'Happiness.Score' : 'Happiness_Score', 
                                      'Economy..GDP.per.Capita.' : 'Economy_GDP_per_Capita', 'Health..Life.Expectancy.' : 'Health_Life_Expectancy',
                                      'Trust..Government.Corruption.' : 'Trust_Government_Corruption', 'Dystopia.Residual' : 'Dystopia_Residual'})

df_16 = df_16.rename(columns = {'Happiness Score' : 'Happiness_Score',"Economy (GDP per Capita)": 'Economy_GDP_per_Capita',
                                "Health (Life Expectancy)":'Health_Life_Expectancy',
                               "Trust (Government Corruption)":'Trust_Government_Corruption',"Dystopia Residual":'Dystopia_Residual'})

df_15 = df_15.rename(columns = {'Happiness Score' : 'Happiness_Score',"Economy (GDP per Capita)": 'Economy_GDP_per_Capita',
                                "Health (Life Expectancy)":'Health_Life_Expectancy',
                               "Trust (Government Corruption)":'Trust_Government_Corruption',"Dystopia Residual":'Dystopia_Residual'})

# %%
df_20['Year']=2020
df_19['Year']=2019
df_18['Year']=2018
df_17['Year']=2017
df_16['Year']=2016
df_15['Year']=2015

# %%
df_20
# Out:
#                       Country  Regional indicator  Happiness_Score  \
# 0                     Finland      Western Europe           7.8087
# 1                     Denmark      Western Europe           7.6456
# 2                 Switzerland      Western Europe           7.5599
# 3                     Iceland      Western Europe           7.5045
# 4                      Norway      Western Europe           7.4880
# ..                        ...                 ...              ...
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# 2                          0.035014      7.628528      7.491272
# 3                          0.059616      7.621347      7.387653
# 4                          0.034837      7.556281      7.419719
# ..                              ...           ...           ...
# 148                        0.115183      3.701658      3.250141
# 149                        0.052425      3.415053      3.209547
# 150                        0.058674      3.414202      3.184198
# 151                        0.107610      3.027516      2.605684
# 152                        0.031311      2.628270      2.505530
#
#      Logged GDP per capita    Family  Healthy life expectancy  \
# 0                10.639267  0.954330                71.900825
# 1                10.774001  0.955991                72.402504
# 2                10.979933  0.942847                74.102448
# 3                10.772559  0.974670                73.000000
# 4                11.087804  0.952487                73.200783
# ..                     ...       ...                      ...
# 148               6.625160  0.319460                45.200001
# 149               7.600104  0.540835                61.098846
# 150               7.865712  0.763093                55.617260
# 151               7.425360  0.553707                51.000000
# 152               7.462861  0.470367                52.590000
#
#      Freedom to make life choices  ...  Ladder score in Dystopia  \
# 0                        0.949172  ...                  1.972317
# 1                        0.951444  ...                  1.972317
# 2                        0.921337  ...                  1.972317
# 3                        0.948892  ...                  1.972317
# 4                        0.955750  ...                  1.972317
# ..                            ...  ...                       ...
# 148                      0.640881  ...                  1.972317
# 149                      0.900589  ...                  1.972317
# 150                      0.711458  ...                  1.972317
# 151                      0.451314  ...                  1.972317
# 152                      0.396573  ...                  1.972317
#
#      Economy_GDP_per_Capita  Explained by: Social support  \
# 0                  1.285190                      1.499526
# 1                  1.326949                      1.503449
# 2                  1.390774                      1.472403
# 3                  1.326502                      1.547567
# 4                  1.424207                      1.495173
# ..                      ...                           ...
# 148                0.041072                      0.000000
# 149                0.343243                      0.522876
# 150                0.425564                      1.047835
# 151                0.289083                      0.553279
# 152                0.300706                      0.356434
#
#      Health_Life_Expectancy   Freedom  Generosity1  \
# 0                  0.961271  0.662317     0.159670
# 1                  0.979333  0.665040     0.242793
# 2                  1.040533  0.628954     0.269056
# 3                  1.000843  0.661981     0.362330
# 4                  1.008072  0.670201     0.287985
# ..                      ...       ...          ...
# 148                0.000000  0.292814     0.253513
# 149                0.572383  0.604088     0.235705
# 150                0.375038  0.377405     0.151349
# 151                0.208809  0.065609     0.209935
# 152                0.266052  0.000000     0.135235
#
#      Trust_Government_Corruption  Dystopia_Residual  Happiness Rank  Year
# 0                       0.477857           2.762835               1  2020
# 1                       0.495260           2.432741               2  2020
# 2                       0.407946           2.350267               3  2020
# 3                       0.144541           2.460688               4  2020
# 4                       0.434101           2.168266               5  2020
# ..                           ...                ...             ...   ...
# 148                     0.028265           2.860198             149  2020
# 149                     0.485542           0.548445             150  2020
# 150                     0.080929           0.841031             151  2020
# 151                     0.111157           1.378751             152  2020
# 152                     0.001226           1.507236             153  2020
#
# [153 rows x 22 columns]

# %%
df_18.columns
# Out:
# Index(['Happiness Rank', 'Country', 'Happiness_Score',
#        'Economy_GDP_per_Capita', 'Family', 'Health_Life_Expectancy', 'Freedom',
#        'Generosity', 'Trust_Government_Corruption', 'Year'],
#       dtype='object')

# %%
df_19["Dystopia_Residual"] = df_19['Happiness_Score'] - df_19['Economy_GDP_per_Capita'] - df_19['Family'] - df_19['Health_Life_Expectancy'] - df_19['Freedom'] - df_19['Generosity'] - df_19['Trust_Government_Corruption']

# %%
df_19
# Out:
#      Happiness Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      Economy_GDP_per_Capita  Family  Health_Life_Expectancy  Freedom  \
# 0                     1.340   1.587                   0.986    0.596
# 1                     1.383   1.573                   0.996    0.592
# 2                     1.488   1.582                   1.028    0.603
# 3                     1.380   1.624                   1.026    0.591
# 4                     1.396   1.522                   0.999    0.557
# ..                      ...     ...                     ...      ...
# 151                   0.359   0.711                   0.614    0.555
# 152                   0.476   0.885                   0.499    0.417
# 153                   0.350   0.517                   0.361    0.000
# 154                   0.026   0.000                   0.105    0.225
# 155                   0.306   0.575                   0.295    0.010
#
#      Generosity  Trust_Government_Corruption  Year  Dystopia_Residual
# 0         0.153                        0.393  2019              2.714
# 1         0.252                        0.410  2019              2.394
# 2         0.271                        0.341  2019              2.241
# 3         0.354                        0.118  2019              2.401
# 4         0.322                        0.298  2019              2.394
# ..          ...                          ...   ...                ...
# 151       0.217                        0.411  2019              0.467
# 152       0.276                        0.147  2019              0.531
# 153       0.158                        0.025  2019              1.792
# 154       0.235                        0.035  2019              2.457
# 155       0.202                        0.091  2019              1.374
#
# [156 rows x 11 columns]

# %%
df_18["Dystopia_Residual"] = df_18['Happiness_Score'] - df_18['Economy_GDP_per_Capita'] - df_18['Family'] - df_18['Health_Life_Expectancy'] - df_18['Freedom'] - df_18['Generosity'] - df_18['Trust_Government_Corruption']

# %%
df_18
# Out:
#      Happiness Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy_GDP_per_Capita  Family  Health_Life_Expectancy  Freedom  \
# 0                     1.305   1.592                   0.874    0.681
# 1                     1.456   1.582                   0.861    0.686
# 2                     1.351   1.590                   0.868    0.683
# 3                     1.343   1.644                   0.914    0.677
# 4                     1.420   1.549                   0.927    0.660
# ..                      ...     ...                     ...      ...
# 151                   0.442   1.073                   0.343    0.244
# 152                   0.455   0.991                   0.381    0.481
# 153                   0.337   0.608                   0.177    0.112
# 154                   0.024   0.000                   0.010    0.305
# 155                   0.091   0.627                   0.145    0.065
#
#      Generosity  Trust_Government_Corruption  Year  Dystopia_Residual
# 0         0.202                        0.393  2018              2.585
# 1         0.286                        0.340  2018              2.383
# 2         0.284                        0.408  2018              2.371
# 3         0.353                        0.138  2018              2.426
# 4         0.256                        0.357  2018              2.318
# ..          ...                          ...   ...                ...
# 151       0.083                        0.064  2018              1.106
# 152       0.270                        0.097  2018              0.628
# 153       0.224                        0.106  2018              1.690
# 154       0.218                        0.038  2018              2.488
# 155       0.149                        0.076  2018              1.752
#
# [156 rows x 11 columns]

# %%
df_2020_clean = df_20[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity1','Trust_Government_Corruption','Dystopia_Residual','Year']]
df_2020_clean
# Out:
#                       Country  Happiness_Score  Economy_GDP_per_Capita  \
# 0                     Finland           7.8087                1.285190
# 1                     Denmark           7.6456                1.326949
# 2                 Switzerland           7.5599                1.390774
# 3                     Iceland           7.5045                1.326502
# 4                      Norway           7.4880                1.424207
# ..                        ...              ...                     ...
# 148  Central African Republic           3.4759                0.041072
# 149                    Rwanda           3.3123                0.343243
# 150                  Zimbabwe           3.2992                0.425564
# 151               South Sudan           2.8166                0.289083
# 152               Afghanistan           2.5669                0.300706
#
#        Family  Health_Life_Expectancy   Freedom  Generosity1  \
# 0    0.954330                0.961271  0.662317     0.159670
# 1    0.955991                0.979333  0.665040     0.242793
# 2    0.942847                1.040533  0.628954     0.269056
# 3    0.974670                1.000843  0.661981     0.362330
# 4    0.952487                1.008072  0.670201     0.287985
# ..        ...                     ...       ...          ...
# 148  0.319460                0.000000  0.292814     0.253513
# 149  0.540835                0.572383  0.604088     0.235705
# 150  0.763093                0.375038  0.377405     0.151349
# 151  0.553707                0.208809  0.065609     0.209935
# 152  0.470367                0.266052  0.000000     0.135235
#
#      Trust_Government_Corruption  Dystopia_Residual  Year
# 0                       0.477857           2.762835  2020
# 1                       0.495260           2.432741  2020
# 2                       0.407946           2.350267  2020
# 3                       0.144541           2.460688  2020
# 4                       0.434101           2.168266  2020
# ..                           ...                ...   ...
# 148                     0.028265           2.860198  2020
# 149                     0.485542           0.548445  2020
# 150                     0.080929           0.841031  2020
# 151                     0.111157           1.378751  2020
# 152                     0.001226           1.507236  2020
#
# [153 rows x 10 columns]

# %%
df_2019_clean = df_19[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity','Trust_Government_Corruption','Dystopia_Residual','Year']]
df_2018_clean = df_18[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity','Trust_Government_Corruption','Dystopia_Residual','Year']]
df_2017_clean = df_17[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity','Trust_Government_Corruption','Dystopia_Residual','Year']]
df_2016_clean = df_16[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity','Trust_Government_Corruption','Dystopia_Residual','Year']]
df_2015_clean = df_15[['Country','Happiness_Score','Economy_GDP_per_Capita','Family','Health_Life_Expectancy','Freedom','Generosity','Trust_Government_Corruption','Dystopia_Residual','Year']]

# %%
output_file_path2020 = "Modified_Resources/new_2020.csv"
df_2020_clean.to_csv(output_file_path2020, index=False)

# %%
output_file_path2019 = "Modified_Resources/new_2019.csv"
df_2019_clean.to_csv(output_file_path2019, index=False)

# %%
output_file_path2018 = "Modified_Resources/new_2018.csv"
df_2018_clean.to_csv(output_file_path2018, index=False)

# %%
output_file_path2017 = "Modified_Resources/new_2017.csv"
df_2017_clean.to_csv(output_file_path2017, index=False)

# %%
output_file_path2016 = "Modified_Resources/new_2016.csv"
df_2016_clean.to_csv(output_file_path2016, index=False)

# %%
output_file_path2015 = "Modified_Resources/new_2015.csv"
df_2015_clean.to_csv(output_file_path2015, index=False)

# %%
# Initial imports
import pandas as pd
# Load the consolidated datasets.
file_pathC = "Modified_Resources/Consolidated_Data"
Consolidated_Scores_df = pd.read_csv(file_pathC)
Consolidated_Scores_df.head(10)
# Out:
#        country  happiness_score  economy_gdp_per_capita    family  \
# 0  Afghanistan           3.5750                0.319820  0.302850
# 1  Afghanistan           3.3600                0.382270  0.110370
# 2  Afghanistan           3.7940                0.401477  0.581543
# 3  Afghanistan           3.6320                0.332000  0.537000
# 4  Afghanistan           3.2030                0.350000  0.517000
# 5  Afghanistan           2.5669                0.300706  0.470367
# 6      Albania           4.9590                0.878670  0.804340
# 7      Albania           4.6550                0.955300  0.501630
# 8      Albania           4.6440                0.996193  0.803685
# 9      Albania           4.5860                0.916000  0.817000
#
#    health_life_expectancy   freedom  generosity1  trust_government_corruption  \
# 0                0.303350  0.234140     0.365100                     0.097190
# 1                0.173440  0.164300     0.312680                     0.071120
# 2                0.180747  0.106180     0.311871                     0.061158
# 3                0.255000  0.085000     0.191000                     0.036000
# 4                0.361000  0.000000     0.158000                     0.025000
# 5                0.266052  0.000000     0.135235                     0.001226
# 6                0.813250  0.357330     0.142720                     0.064130
# 7                0.730070  0.318660     0.168400                     0.053010
# 8                0.731160  0.381499     0.201313                     0.039864
# 9                0.790000  0.419000     0.149000                     0.032000
#
#    dystopia_residual  year
# 0           1.952100  2015
# 1           2.145580  2016
# 2           2.150801  2017
# 3           2.196000  2018
# 4           1.792000  2019
# 5           1.507236  2020
# 6           1.898940  2015
# 7           1.928160  2016
# 8           1.490442  2017
# 9           1.463000  2018

# %%
output_file_pathC = "Modified_Resources/Consolidated_Scores.csv"
Consolidated_Scores_df.to_csv(output_file_pathC, index=False)
